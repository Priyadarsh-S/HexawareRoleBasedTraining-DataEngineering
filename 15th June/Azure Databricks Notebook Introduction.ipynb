# %%
data = [
    (101, "Rahul Sharma", "Hyderabad", "Electronics", 65000),
    (102, "Priya Reddy", "Bangalore", "Electronics", 25000),
    (103, "Amit Kumar", "Mumbai", "Furniture", 12000),
    (104, "Sneha Patel", "Chennai", "Fashion", 8000),
    (105, "Farhan Ali", "Delhi", "Electronics", 45000)
]
 
columns = [
    "order_id",
    "customer_name",
    "city",
    "category",
    "amount"
]
 
df = spark.createDataFrame(data, columns)
 
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>category</th><th>amount</th></tr></thead><tbody><tr><td>101</td><td>Rahul Sharma</td><td>Hyderabad</td><td>Electronics</td><td>65000</td></tr><tr><td>102</td><td>Priya Reddy</td><td>Bangalore</td><td>Electronics</td><td>25000</td></tr><tr><td>103</td><td>Amit Kumar</td><td>Mumbai</td><td>Furniture</td><td>12000</td></tr><tr><td>104</td><td>Sneha Patel</td><td>Chennai</td><td>Fashion</td><td>8000</td></tr><tr><td>105</td><td>Farhan Ali</td><td>Delhi</td><td>Electronics</td><td>45000</td></tr></tbody></table></div>
