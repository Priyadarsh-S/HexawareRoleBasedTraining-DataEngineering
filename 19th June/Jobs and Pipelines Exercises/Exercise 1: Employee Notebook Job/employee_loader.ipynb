# %%
employee_data = [
    (101, "Alice Smith", "Engineering", 85000),
    (102, "Bob Jones", "Marketing", 65000),
    (103, "Charlie Brown", "Engineering", 90000),
    (104, "Diana Prince", "Finance", 95000),
    (105, "Evan Wright", "HR", 55000)
]
schema = ["emp_id", "name", "department", "salary"]
employee_df = spark.createDataFrame(employee_data, schema=schema)
display(employee_df)
print("Employee Load Completed")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Alice Smith</td><td>Engineering</td><td>85000</td></tr><tr><td>102</td><td>Bob Jones</td><td>Marketing</td><td>65000</td></tr><tr><td>103</td><td>Charlie Brown</td><td>Engineering</td><td>90000</td></tr><tr><td>104</td><td>Diana Prince</td><td>Finance</td><td>95000</td></tr><tr><td>105</td><td>Evan Wright</td><td>HR</td><td>55000</td></tr></tbody></table></div>
# Employee Load Completed
